# %%
import pickle
infile=open('db2','rb')
db=pickle.load(infile)
infile.close()

# %%
db
# Out:
#                                                      URL  \
# 0      https://www.vegrecipesofindia.com/eggless-date...
# 1      https://www.vegrecipesofindia.com/eggless-oran...
# 2      https://www.vegrecipesofindia.com/eggless-bana...
# 3      https://www.vegrecipesofindia.com/punjabi-chol...
# 4      https://www.vegrecipesofindia.com/idli-recipe-...
# ...                                                  ...
# 13834  https://www.sanjeevkapoor.com/Recipe/Kozhi-Var...
# 13835  https://www.sanjeevkapoor.com/Recipe/Besan-ke-...
# 13836  https://www.sanjeevkapoor.com/Recipe/Besan-ki-...
# 13837  https://www.sanjeevkapoor.com/Recipe/Chocolate...
# 13838  https://www.sanjeevkapoor.com/Recipe/Corn-And-...
#
#                                                     Dish  \
# 0            Easy Date And Walnut Cake (Eggless + Vegan)
# 1             Orange Cake (Whole Wheat, Eggless & Vegan)
# 2            Whole Wheat Banana Cake (Eggless And Vegan)
# 3      Chana Masala | Punjabi Chole Masala (Stovetop ...
# 4                  Idli Recipe | How To Make Idli Batter
# ...                                                  ...
# 13834                                  Kozhi Vartha Kari
# 13835                                    Besan ke Laddoo
# 13836                                     Besan ki Burfi
# 13837                                    Chocolate Burfi
# 13838                              Corn And Cheese Balls
#
#                               Cuisine  Total Time  \
# 0                   (World, All, All)  (0, 1, 20)
# 1                   (World, All, All)  (0, 0, 55)
# 2              (World, American, All)  (0, 0, 40)
# 3                (Indian, North, All)  (0, 9, 45)
# 4                (Indian, South, All)  (0, 9, 25)
# ...                               ...         ...
# 13834         (Indian, South, Kerala)  (0, 0, 57)
# 13835   (Indian, West, Maharashtrian)  (0, 0, 42)
# 13836  (Indian, North, Uttar Pradesh)  (0, 0, 57)
# 13837              (Indian, All, All)  (0, 0, 42)
# 13838            (World, Fusion, All)  (0, 0, 27)
#
#                                              Ingredients    Style
# 0      [baking powder, water, whole wheat flour, vani...    Vegan
# 1      [regular fine sugar, olive oil, orange juice, ...    Vegan
# 2      [baking powder, baking soda, whole wheat flour...    Vegan
# 3      [cumin seeds, water / the stock in which the c...    Vegan
# 4      [thick poha / thick poha flattened rice, oil a...    Vegan
# ...                                                  ...      ...
# 13834  [chicken, dry red chillies, ginger, garlic, re...  Non-Veg
# 13835  [coarse gram flour (besan), cashew, almonds, g...      Veg
# 13836  [gram flour (besan), green cardamom powder, pi...      Veg
# 13837  [cocoa powder, khoya/mawa, sugar, liquid gluco...      Veg
# 13838  [sweet corn kernels, processed cheese, potatoe...      Veg
#
# [13839 rows x 6 columns]

# %%
df_list=db.copy()

# %%
import pandas as pd
first_ques=df_list['Style'].unique().tolist()
first_ans=['Vegan']
first_ans1=df_list.where(df_list['Style']==first_ans[0]).dropna()
for i in range(1,len(first_ans)):
    test=df_list.where(df_list['Style']==first_ans[i]).dropna()
    first_ans1=pd.concat([first_ans1,test])
first_ans1=first_ans1.reset_index()

# %%
first_ans1
# Out:
#      index                                                URL  \
# 0        0  https://www.vegrecipesofindia.com/eggless-date...
# 1        1  https://www.vegrecipesofindia.com/eggless-oran...
# 2        2  https://www.vegrecipesofindia.com/eggless-bana...
# 3        3  https://www.vegrecipesofindia.com/punjabi-chol...
# 4        4  https://www.vegrecipesofindia.com/idli-recipe-...
# ..     ...                                                ...
# 810   2048  https://www.sanjeevkapoor.com/Recipe/Vegan-Mal...
# 811   2049  https://www.sanjeevkapoor.com/Recipe/Vegan-Kad...
# 812   2075  https://www.sanjeevkapoor.com/Recipe/Vegan-Guj...
# 813   2264  https://www.sanjeevkapoor.com/Recipe/Vegan-Sha...
# 814   4104  https://www.sanjeevkapoor.com/Recipe/Vegan-Pol...
#
#                                                   Dish  \
# 0          Easy Date And Walnut Cake (Eggless + Vegan)
# 1           Orange Cake (Whole Wheat, Eggless & Vegan)
# 2          Whole Wheat Banana Cake (Eggless And Vegan)
# 3    Chana Masala | Punjabi Chole Masala (Stovetop ...
# 4                Idli Recipe | How To Make Idli Batter
# ..                                                 ...
# 810                                   Vegan Malai Peda
# 811                                        Vegan Kadhi
# 812                                       Vegan Gujiya
# 813                                 Vegan Shahi Paneer
# 814  Vegan Polenta Cakes with Stirfried Veggies and...
#
#                     Cuisine  Total Time  \
# 0         (World, All, All)  (0, 1, 20)
# 1         (World, All, All)  (0, 0, 55)
# 2    (World, American, All)  (0, 0, 40)
# 3      (Indian, North, All)  (0, 9, 45)
# 4      (Indian, South, All)  (0, 9, 25)
# ..                      ...         ...
# 810      (Indian, All, All)  (0, 0, 16)
# 811      (Indian, All, All)  (0, 0, 42)
# 812      (Indian, All, All)   (0, 1, 2)
# 813      (Indian, All, All)  (0, 0, 47)
# 814    (World, Fusion, All)  (0, 0, 52)
#
#                                            Ingredients  Style
# 0    [baking powder, water, whole wheat flour, vani...  Vegan
# 1    [regular fine sugar, olive oil, orange juice, ...  Vegan
# 2    [baking powder, baking soda, whole wheat flour...  Vegan
# 3    [cumin seeds, water / the stock in which the c...  Vegan
# 4    [thick poha / thick poha flattened rice, oil a...  Vegan
# ..                                                 ...    ...
# 810  [cashew, almond powder, dry date (kharik) powd...  Vegan
# 811  [vegan yogurt, gram flour (besan), raisins, on...  Vegan
# 812  [desiccated coconut, whole wheat flour (atta),...  Vegan
# 813  [tofu, cashew yogurt, onions, melon seeds, pop...  Vegan
# 814  [polenta, garlic, oil, vegetable stock, crushe...  Vegan
#
# [815 rows x 7 columns]

# %%
second_ques=['World','Indian','Both']
second_ans='Indian'
if(second_ans=='World'):
    third_ques=['African',
 'American',
 'British',
 'Australian',
 'Brazilian',
 'Fusion',
 'Burmese',
 'Canadian',
 'Carribean',
 'Chinese',
 'Continental',
 'Cuban',
 'Denmark',
 'East',#nkjnlknkkkkkkkkkkkkkkkkkkkkkkkkkkk
 'French',
 'Italian',
 'German',
 'Greek',
 'Indo Chinese',
 'Indonesian',
 'Malaysian',
 'Thai',
 'Irish',
 'Spanish',
 'Jamaican',
 'Japanese',
 'Korean',
 'Lebanese',
 'Malvani',#Vvvvvvvvvvvvvvvvvvvvvvvvvvv
 'Mexican',
 'Middle Eastern',
 'Mongolian',
 'Moroccan',
 'Pakistani',
 'Parsi',
 'Peruvian',
 'Polish',
 'Portuguese',
 'Rome',
 'Russian',
 'Scottish',
 'Sindhi',
 'Singaporean',
 'South African',
 'Sri Lankan',
 'Swiss',
 'Tibetian',
 'Turkish',
 'Viennese',
 'Vietnamese']
elif(second_ans=='Indian'):
    third_ques=['North','South','West','East','Street Food']
else:
    third_ques skip

# %%
t=[]
for i in range(len(db)):
    if(db.iloc[i][2][0]=='World'):
        t.append(db.iloc[i][2][1])

# %%
set(t)
# Out:
# {'African',
#  'All',
#  'America/Fusion',
#  'American',
#  'American/British',
#  'Australian',
#  'Brazilian',
#  'British',
#  'British/Fusion',
#  'Burmese',
#  'Canadian',
#  'Carribean',
#  'Chinese',
#  'Chinese/Fusion',
#  'Continental',
#  'Cuban',
#  'Denmark',
#  'East',
#  'French',
#  'French/Fusion',
#  'Fusion',
#  'Fusion/French',
#  'Fusion/Italian',
#  'German',
#  'Greek',
#  'Indo Chinese',
#  'Indo-Chinese/Fusion',
#  'Indonesian',
#  'Indonesian/Malaysian',
#  'Indonesian/Malaysian/Thai',
#  'Irish',
#  'Italian',
#  'Italian/British/Fusion',
#  'Italian/Spanish',
#  'Jamaican',
#  'Japanese',
#  'Korean',
#  'Korean/Fusion',
#  'Lebanese',
#  'Malaysian',
#  'Malaysian/Singaporean',
#  'Malvani',
#  'Mexican',
#  'Middle Eastern',
#  'Middle Eastern/Fusion',
#  'Mongolian',
#  'Moroccan',
#  'Pakistani',
#  'Parsi',
#  'Peruvian',
#  'Polish',
#  'Portuguese',
#  'Rome',
#  'Russian',
#  'Scottish',
#  'Sindhi',
#  'Singaporean',
#  'South African',
#  'Spanish',
#  'Spanish/Italian',
#  'Sri Lankan',
#  'Swiss',
#  'Thai',
#  'Thai/Malaysian/Singaporean/Indonesian',
#  'Tibetian',
#  'Turkish',
#  'Viennese',
#  'Vietnamese'}

# %%
third_ques=['African',
 'American',
 'British',
 'Australian',
 'Brazilian',
 'Fusion',
 'Burmese',
 'Canadian',
 'Carribean',
 'Chinese',
 'Continental',
 'Cuban',
 'Denmark',
 'East',#nkjnlknkkkkkkkkkkkkkkkkkkkkkkkkkkk
 'French',
 'Italian',
 'German',
 'Greek',
 'Indo Chinese',
 'Indonesian',
 'Malaysian',
 'Thai',
 'Irish',
 'Spanish',
 'Jamaican',
 'Japanese',
 'Korean',
 'Lebanese',
 'Malaysian',
 'Malvani',#Vvvvvvvvvvvvvvvvvvvvvvvvvvv
 'Mexican',
 'Middle Eastern',
 'Mongolian',
 'Moroccan',
 'Pakistani',
 'Parsi',
 'Peruvian',
 'Polish',
 'Portuguese',
 'Rome',
 'Russian',
 'Scottish',
 'Sindhi',
 'Singaporean',
 'South African',
 'Sri Lankan',
 'Swiss',
 'Tibetian',
 'Turkish',
 'Viennese',
 'Vietnamese']

# %%
len(set(third_ques))
# Out:
# 50

# %%
sorted(third_ques)
# Out:
# ['African',
#  'American',
#  'Australian',
#  'Brazilian',
#  'British',
#  'Burmese',
#  'Canadian',
#  'Carribean',
#  'Chinese',
#  'Continental',
#  'Cuban',
#  'Denmark',
#  'East',
#  'French',
#  'Fusion',
#  'German',
#  'Greek',
#  'Indo Chinese',
#  'Indonesian',
#  'Irish',
#  'Italian',
#  'Jamaican',
#  'Japanese',
#  'Korean',
#  'Lebanese',
#  'Malaysian',
#  'Malaysian',
#  'Malvani',
#  'Mexican',
#  'Middle Eastern',
#  'Mongolian',
#  'Moroccan',
#  'Pakistani',
#  'Parsi',
#  'Peruvian',
#  'Polish',
#  'Portuguese',
#  'Rome',
#  'Russian',
#  'Scottish',
#  'Sindhi',
#  'Singaporean',
#  'South African',
#  'Spanish',
#  'Sri Lankan',
#  'Swiss',
#  'Thai',
#  'Tibetian',
#  'Turkish',
#  'Viennese',
#  'Vietnamese']

# %%
import streamlit as st

# %%
import pandas as pd
import numpy as np

x = st.slider('x')
st.write(x, 'squared is', x * x)

# %%
second_ques=['Any','<30 mins','<1 hour','1-3 hours','More']

# %%
db
# Out:
#                                                      URL  \
# 0      https://www.vegrecipesofindia.com/eggless-date...
# 1      https://www.vegrecipesofindia.com/eggless-oran...
# 2      https://www.vegrecipesofindia.com/eggless-bana...
# 3      https://www.vegrecipesofindia.com/punjabi-chol...
# 4      https://www.vegrecipesofindia.com/idli-recipe-...
# ...                                                  ...
# 13834  https://www.sanjeevkapoor.com/Recipe/Kozhi-Var...
# 13835  https://www.sanjeevkapoor.com/Recipe/Besan-ke-...
# 13836  https://www.sanjeevkapoor.com/Recipe/Besan-ki-...
# 13837  https://www.sanjeevkapoor.com/Recipe/Chocolate...
# 13838  https://www.sanjeevkapoor.com/Recipe/Corn-And-...
#
#                                                     Dish  \
# 0            Easy Date And Walnut Cake (Eggless + Vegan)
# 1             Orange Cake (Whole Wheat, Eggless & Vegan)
# 2            Whole Wheat Banana Cake (Eggless And Vegan)
# 3      Chana Masala | Punjabi Chole Masala (Stovetop ...
# 4                  Idli Recipe | How To Make Idli Batter
# ...                                                  ...
# 13834                                  Kozhi Vartha Kari
# 13835                                    Besan ke Laddoo
# 13836                                     Besan ki Burfi
# 13837                                    Chocolate Burfi
# 13838                              Corn And Cheese Balls
#
#                               Cuisine  Total Time  \
# 0                   (World, All, All)  (0, 1, 20)
# 1                   (World, All, All)  (0, 0, 55)
# 2              (World, American, All)  (0, 0, 40)
# 3                (Indian, North, All)  (0, 9, 45)
# 4                (Indian, South, All)  (0, 9, 25)
# ...                               ...         ...
# 13834         (Indian, South, Kerala)  (0, 0, 57)
# 13835   (Indian, West, Maharashtrian)  (0, 0, 42)
# 13836  (Indian, North, Uttar Pradesh)  (0, 0, 57)
# 13837              (Indian, All, All)  (0, 0, 42)
# 13838            (World, Fusion, All)  (0, 0, 27)
#
#                                              Ingredients    Style
# 0      [baking powder, water, whole wheat flour, vani...    Vegan
# 1      [regular fine sugar, olive oil, orange juice, ...    Vegan
# 2      [baking powder, baking soda, whole wheat flour...    Vegan
# 3      [cumin seeds, water / the stock in which the c...    Vegan
# 4      [thick poha / thick poha flattened rice, oil a...    Vegan
# ...                                                  ...      ...
# 13834  [chicken, dry red chillies, ginger, garlic, re...  Non-Veg
# 13835  [coarse gram flour (besan), cashew, almonds, g...      Veg
# 13836  [gram flour (besan), green cardamom powder, pi...      Veg
# 13837  [cocoa powder, khoya/mawa, sugar, liquid gluco...      Veg
# 13838  [sweet corn kernels, processed cheese, potatoe...      Veg
#
# [13839 rows x 6 columns]

# %%
db.where(sum(db['Total Time'])<=60).dropna()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a34a99e66b26> in <module>
# ----> 1 db.where(sum(db['Total Time'])<=60).dropna()
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
db['Total Time'][0]
# Out:
# (0, 1, 20)

# %%
db['Time']=db['Total Time'].map(lambda x:x[0]*24*60+x[1]*60+x[2])

# %%
db
# Out:
#                                                      URL  \
# 0      https://www.vegrecipesofindia.com/eggless-date...
# 1      https://www.vegrecipesofindia.com/eggless-oran...
# 2      https://www.vegrecipesofindia.com/eggless-bana...
# 3      https://www.vegrecipesofindia.com/punjabi-chol...
# 4      https://www.vegrecipesofindia.com/idli-recipe-...
# ...                                                  ...
# 13834  https://www.sanjeevkapoor.com/Recipe/Kozhi-Var...
# 13835  https://www.sanjeevkapoor.com/Recipe/Besan-ke-...
# 13836  https://www.sanjeevkapoor.com/Recipe/Besan-ki-...
# 13837  https://www.sanjeevkapoor.com/Recipe/Chocolate...
# 13838  https://www.sanjeevkapoor.com/Recipe/Corn-And-...
#
#                                                     Dish  \
# 0            Easy Date And Walnut Cake (Eggless + Vegan)
# 1             Orange Cake (Whole Wheat, Eggless & Vegan)
# 2            Whole Wheat Banana Cake (Eggless And Vegan)
# 3      Chana Masala | Punjabi Chole Masala (Stovetop ...
# 4                  Idli Recipe | How To Make Idli Batter
# ...                                                  ...
# 13834                                  Kozhi Vartha Kari
# 13835                                    Besan ke Laddoo
# 13836                                     Besan ki Burfi
# 13837                                    Chocolate Burfi
# 13838                              Corn And Cheese Balls
#
#                               Cuisine  Total Time  \
# 0                   (World, All, All)  (0, 1, 20)
# 1                   (World, All, All)  (0, 0, 55)
# 2              (World, American, All)  (0, 0, 40)
# 3                (Indian, North, All)  (0, 9, 45)
# 4                (Indian, South, All)  (0, 9, 25)
# ...                               ...         ...
# 13834         (Indian, South, Kerala)  (0, 0, 57)
# 13835   (Indian, West, Maharashtrian)  (0, 0, 42)
# 13836  (Indian, North, Uttar Pradesh)  (0, 0, 57)
# 13837              (Indian, All, All)  (0, 0, 42)
# 13838            (World, Fusion, All)  (0, 0, 27)
#
#                                              Ingredients    Style  Time
# 0      [baking powder, water, whole wheat flour, vani...    Vegan    80
# 1      [regular fine sugar, olive oil, orange juice, ...    Vegan    55
# 2      [baking powder, baking soda, whole wheat flour...    Vegan    40
# 3      [cumin seeds, water / the stock in which the c...    Vegan   585
# 4      [thick poha / thick poha flattened rice, oil a...    Vegan   565
# ...                                                  ...      ...   ...
# 13834  [chicken, dry red chillies, ginger, garlic, re...  Non-Veg    57
# 13835  [coarse gram flour (besan), cashew, almonds, g...      Veg    42
# 13836  [gram flour (besan), green cardamom powder, pi...      Veg    57
# 13837  [cocoa powder, khoya/mawa, sugar, liquid gluco...      Veg    42
# 13838  [sweet corn kernels, processed cheese, potatoe...      Veg    27
#
# [13839 rows x 7 columns]

# %%
db.where(db['Time']<=30).dropna()
# Out:
# 2020-08-25 22:40:50.187 INFO    numexpr.utils: Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2020-08-25 22:40:50.246 INFO    numexpr.utils: NumExpr defaulting to 8 threads.
#                                                      URL  \
# 9      https://www.vegrecipesofindia.com/restaurant-s...
# 10     https://www.vegrecipesofindia.com/upma-savoury...
# 13     https://www.vegrecipesofindia.com/tomato-rasam...
# 16     https://www.vegrecipesofindia.com/khaman-dhokl...
# 17     https://www.vegrecipesofindia.com/kaju-katli-r...
# ...                                                  ...
# 13827  https://www.sanjeevkapoor.com/Recipe/Sausage-S...
# 13830  https://www.sanjeevkapoor.com/Recipe/Banana-Ha...
# 13831  https://www.sanjeevkapoor.com/Recipe/Palak-Pan...
# 13832  https://www.sanjeevkapoor.com/Recipe/Self-Sauc...
# 13838  https://www.sanjeevkapoor.com/Recipe/Corn-And-...
#
#                                                     Dish  \
# 9                   Dal Tadka (Stovetop And Instant Pot)
# 10                               Upma Recipe | Rava Upma
# 13     Tomato Rasam (2 Tasty Ways) | Easy Tomato Rasa...
# 16     Khaman Dhokla Recipe | Khaman Recipe | Besan D...
# 17                     Perfect Kaju Katli (Cashew Fudge)
# ...                                                  ...
# 13827                           Sausage Stuffed Chillies
# 13830                                 Banana Halwa Burfi
# 13831                                       Palak Paneer
# 13832          Self Saucing Chocolate And Coffee Pudding
# 13838                              Corn And Cheese Balls
#
#                         Cuisine  Total Time  \
# 9          (Indian, North, All)  (0, 0, 30)
# 10           (Indian, All, All)  (0, 0, 30)
# 13         (Indian, South, All)  (0, 0, 25)
# 16     (Indian, West, Gujarati)  (0, 0, 20)
# 17           (Indian, All, All)  (0, 0, 20)
# ...                         ...         ...
# 13827      (World, Fusion, All)  (0, 0, 22)
# 13830        (Indian, All, All)  (0, 0, 22)
# 13831  (Indian, North, Punjabi)  (0, 0, 17)
# 13832      (World, Fusion, All)  (0, 0, 22)
# 13838      (World, Fusion, All)  (0, 0, 27)
#
#                                              Ingredients    Style  Time
# 9      [cumin seeds, arhar dal tuvar dal / split pige...    Vegan  30.0
# 10     [green chilli, fine rawa sooji / cream wheat /...    Vegan  30.0
# 13     [garlic cloves, turmeric powder, cumin seeds, ...    Vegan  25.0
# 16     [turmeric powder, cumin seeds, asafoetida hing...    Vegan  20.0
# 17     [rose petals rose water, sugar sugar, ghee / c...    Vegan  20.0
# ...                                                  ...      ...   ...
# 13827  [sausages, bhavnagri green chillies, oil, onio...  Non-Veg  22.0
# 13830  [ripe bananas, maw (khoya), sugar, ghee, cashe...      Veg  22.0
# 13831  [spinach, paneer (cottage cheese), green chill...      Veg  17.0
# 13832  [dark chocolate, instant coffee powder, butter...      Veg  22.0
# 13838  [sweet corn kernels, processed cheese, potatoe...      Veg  27.0
#
# [5483 rows x 7 columns]

# %%
db
# Out:
#                                                      URL  \
# 0      https://www.vegrecipesofindia.com/eggless-date...
# 1      https://www.vegrecipesofindia.com/eggless-oran...
# 2      https://www.vegrecipesofindia.com/eggless-bana...
# 3      https://www.vegrecipesofindia.com/punjabi-chol...
# 4      https://www.vegrecipesofindia.com/idli-recipe-...
# ...                                                  ...
# 13834  https://www.sanjeevkapoor.com/Recipe/Kozhi-Var...
# 13835  https://www.sanjeevkapoor.com/Recipe/Besan-ke-...
# 13836  https://www.sanjeevkapoor.com/Recipe/Besan-ki-...
# 13837  https://www.sanjeevkapoor.com/Recipe/Chocolate...
# 13838  https://www.sanjeevkapoor.com/Recipe/Corn-And-...
#
#                                                     Dish  \
# 0            Easy Date And Walnut Cake (Eggless + Vegan)
# 1             Orange Cake (Whole Wheat, Eggless & Vegan)
# 2            Whole Wheat Banana Cake (Eggless And Vegan)
# 3      Chana Masala | Punjabi Chole Masala (Stovetop ...
# 4                  Idli Recipe | How To Make Idli Batter
# ...                                                  ...
# 13834                                  Kozhi Vartha Kari
# 13835                                    Besan ke Laddoo
# 13836                                     Besan ki Burfi
# 13837                                    Chocolate Burfi
# 13838                              Corn And Cheese Balls
#
#                               Cuisine  Total Time  \
# 0                   (World, All, All)  (0, 1, 20)
# 1                   (World, All, All)  (0, 0, 55)
# 2              (World, American, All)  (0, 0, 40)
# 3                (Indian, North, All)  (0, 9, 45)
# 4                (Indian, South, All)  (0, 9, 25)
# ...                               ...         ...
# 13834         (Indian, South, Kerala)  (0, 0, 57)
# 13835   (Indian, West, Maharashtrian)  (0, 0, 42)
# 13836  (Indian, North, Uttar Pradesh)  (0, 0, 57)
# 13837              (Indian, All, All)  (0, 0, 42)
# 13838            (World, Fusion, All)  (0, 0, 27)
#
#                                              Ingredients    Style  Time
# 0      [baking powder, water, whole wheat flour, vani...    Vegan    80
# 1      [regular fine sugar, olive oil, orange juice, ...    Vegan    55
# 2      [baking powder, baking soda, whole wheat flour...    Vegan    40
# 3      [cumin seeds, water / the stock in which the c...    Vegan   585
# 4      [thick poha / thick poha flattened rice, oil a...    Vegan   565
# ...                                                  ...      ...   ...
# 13834  [chicken, dry red chillies, ginger, garlic, re...  Non-Veg    57
# 13835  [coarse gram flour (besan), cashew, almonds, g...      Veg    42
# 13836  [gram flour (besan), green cardamom powder, pi...      Veg    57
# 13837  [cocoa powder, khoya/mawa, sugar, liquid gluco...      Veg    42
# 13838  [sweet corn kernels, processed cheese, potatoe...      Veg    27
#
# [13839 rows x 7 columns]

# %%
for i in range(len(db)):
    if(db.iloc[i][2][0]=='World' and db.iloc[i][2][1]=='Malvani'):#lol
        print(i)
# Out:
# 2366

# %%
db.at[3544, 'Cuisine'] = ('India','East','All')
db.at[2366, 'Cuisine'] = ('India','West','Malvani')
# db.at[1881,'Cuisine']=('World', 'Indo-Chinese/Fusion','All')
# db.at[1943,'Cuisine']=('World', 'Indo-Chinese/Fusion','All')
# db.at[2041,'Cuisine']=('World', 'Indo-Chinese/Fusion','All')
# db.at[2142,'Cuisine']=('World', 'Fusion/Italian','All')
# db.at[2181,'Cuisine']=('World', 'Fusion/Italian','All')
# db.at[2204,'Cuisine']=('World', 'Fusion/French','All')
# db.at[2221,'Cuisine']=('World', 'Indo-Chinese/Fusion','All')
# db.at[2225,'Cuisine']=('World', 'Fusion/French','All')

# %%
change={('World', 'Indo-Chinese/Fusion'):('World', 'Indo-Chinese/Fusion','All'),('World', 'Fusion/French'):('World', 'Fusion/French','All'),('World', 'Fusion/Italian'):('World', 'Fusion/Italian','All'),
       ('World', 'French'):('World', 'French','All'),('Indian', 'Lebanese/Middle Eastern', 'All'):('World', 'Lebanese/Middle Eastern', 'All'),
       ('Indian', 'Chinese', 'All'):('World', 'Chinese', 'All'),('Indian', 'Bengali/Fusion', 'All'):('Indian', 'Fusion', 'Bengali')}

# %%
for i in range(len(db)):
    if(db.iloc[i][2] in change):
        db.at[i,'Cuisine']=change[db.iloc[i][2]]

# %%
db.iloc[2366][2]
# Out:
# ('India', 'West', 'Malvani')

# %%
fourth_ques=['Any','African','American', 'British', 'Australian', 'Brazilian', 'Fusion', 'Burmese', 'Canadian', 'Carribean', 'Chinese', 'Continental',            
'Cuban','Denmark','French','Italian','German','Greek','Indo Chinese','Indonesian','Malaysian','Thai','Irish','Spanish','Jamaican','Japanese',
 'Korean', 'Lebanese', 'Malaysian', 'Mexican', 'Middle Eastern', 'Mongolian', 'Moroccan', 'Pakistani', 'Parsi', 'Peruvian', 'Polish', 'Portuguese',
 'Rome','Russian','Scottish','Sindhi','Singaporean','South African','Sri Lankan','Swiss','Tibetian','Turkish','Viennese','Vietnamese']

# %%
db['Cuisine1']=None
db['Cuisine2']=None
db['Cuisine3']=None

# %%
for i in range(len(db)):
    db.at[i,'Cuisine1']=db.iloc[i][2][0]
    db.at[i,'Cuisine2']=db.iloc[i][2][1]
    db.at[i,'Cuisine3']=db.iloc[i][2][2]

# %%
import pickle
pickle.dump(db,open('db3.p','wb'))

# %%
test=db.where(db['Cuisine1']=='Indian').dropna()

# %%
test.Cuisine2.unique()
# Out:
# array(['North', 'South', 'All', 'West', 'Street Food', 'South/West',
#        'East', 'Street Food/South', 'Mughlai/North', 'North/Street Food',
#        'Mughlai', 'West/South', 'Fusion', 'North/West/South',
#        'North/South'], dtype=object)

# %%
test.where(test['Cuisine2']=='Bengali/Fusion').dropna()
# Out:
#                                                     URL              Dish  \
# 3343  https://www.sanjeevkapoor.com/Recipe/Baked-Mis...  Baked Mishti Doi
#
#                             Cuisine  Total Time  \
# 3343  (Indian, Bengali/Fusion, All)  (0, 1, 21)
#
#                                             Ingredients Style  Time Cuisine1  \
# 3343  [yogurt, condensed milk, cream, nolen gur melted]   Veg  81.0   Indian
#
#             Cuisine2 Cuisine3
# 3343  Bengali/Fusion      All

# %%
testn=test.where(test['Cuisine2']=='North').dropna()

# %%
testn.Cuisine3.unique()
# Out:
# array(['All', 'Punjabi', 'Uttar Pradesh', 'Kashmiri', 'Rajasthani',
#        'Bihari', 'Uttar Pradesh/Banarasi', 'Awadhi',
#        'Uttar Pradesh/Awadhi', 'Jammu', 'Madhya Pradesh', 'Marwadi',
#        'Uttar Pradesh/Punjabi'], dtype=object)

# %%
tests=test.where(test['Cuisine2']=='South').dropna()

# %%
tests.Cuisine3.unique()
# Out:
# array(['All', 'Tamil Nadu', 'Andhra', 'Karnataka', 'Kerala', 'Hyderabadi',
#        'Mangalorean', 'Andhra/Karnataka/Tamil Nadu', 'Chettinad',
#        'Karnataka/Tamil Nadu', 'Tamil Nadu/Kerala',
#        'Kerala/Karnataka/Tamil Nadu', 'Andhra/Kerala',
#        'Kerala/Tamil Nadu', 'Kerala/Karnataka'], dtype=object)

# %%
testw=test.where(test['Cuisine2']=='West').dropna()

# %%
testw.Cuisine3.unique()
# Out:
# array(['Gujarati', 'Maharashtrian', 'Goan', 'Konkani & Malvani',
#        'Maharashtrian/Gujarati', 'Konkani & Malvani/Maharashtrian',
#        'Goan/Konkani & Malvani', 'Goan/Konkani & Malvani/Maharashtrian',
#        'Gujarati/Maharashtrian'], dtype=object)

# %%
teste=test.where(test['Cuisine2']=='East').dropna()

# %%
teste.Cuisine3.unique()
# Out:
# array(['Bengali', 'Odisha', 'Bihari', 'Assam'], dtype=object)

# %%
testsf=test.where(test['Cuisine2']=='Street Food').dropna()

# %%
testsf.Cuisine3.unique()
# Out:
# array(['Mumbai', 'All', 'Bengali', 'Maharashtrian', 'Indore'],
#       dtype=object)

# %%
testm=test.where(test['Cuisine2']=='Mughlai').dropna()

# %%
testm.Cuisine3.unique()
# Out:
# array(['All'], dtype=object)

# %%
testf=test.where(test['Cuisine2']=='Fusion').dropna()

# %%
testf.Cuisine3.unique()
# Out:
# array(['Bengali', 'All'], dtype=object)

# %%
vocabnew=[
    'Salt/Namak','Water/Paani','Oil/Tel','Turmeric Powder/Haldi','Ginger/Adrak','Asafoetida/Hing',
    'Coriander Leaves/Dhania Patta','Cumin Seeds/Jeera','Curry Leaves/Kadhi Patta','Red Chilli Powder/Lal Mirch',
    'Green Chilli/Hari Mirch','Mustard Seeds/Rai','Onion/Pyaaz','Tomato/Tamatar','Lemon Juice/Lime Juice/Nimbu Ras','Cumin Powder/Jeera Powder',
    'Clove/Laung','Cinnamon/Dal Cheeni','Garlic/Lahsun','Green Cardamom/Choti Elaichi',
    'Coriander Powder/Dhania Powder','Coconut/Nariyal','Potato/Aloo','Indian Bay Leaf/Tej Patta','Cashew/Kaju','Red Chilli/Lal Mirch','Black Pepper Powder/Kaali Mirch Powder',
    'Baking Soda','Chaat Masala','Clarified Butter/Ghee','Chickpea Flour/Besan','Mint Leaves/Pudina Patta','Peanuts/Moong Fali','Wheat Flour/Atta',
    'Rice Flour/Chawal Atta','Carrot/Gajar','Coriander Seeds/Dhania Beej','Jaggery/Gur','Black Salt/Kala Namak','Coconut Oil/Nariyal Tel','Mango Powder/Amchur Powder','Saffron/Kesar',
    'Cardamom Powder/Elaichi Powder','Black Cardamom/Badi Elaichi','Carrom Seeds/Ajwain','Fennel Seeds/Saunf','Peas/Matar','Black Gram/Urad Dal','Basmati Rice/Basmati Chawal','Fenugreek Leaves/Kasuri Methi',
    'Cilantro Leaves/Dhania Patta','Tamarind/Imli','Sesame Seeds/Til','Mustard Oil/Sarso Tel','Beans/Gwar Fali','Mace/Javitri','Almond/Badam','Celery/Ajwain Patta','Cottage Cheese/Paneer','Milk/Doodh','Baking Powder','All Purpose Flour/Maida','Butter/Margarine/Makhan','Ice/Baraf',
    'Fenugreek Seeds/Methi','Curd/Yogurt/Dahi','Cream/Malai','Cabbage/Patta Gobi','Raisins/KishMish','Tapioca Pearls/Sabudana','Olive Oil','Soy Sauce','Sesame Oil/Til Tel','Cauliflower/Gobi','Bengal Gram/Chana Dal',
    'Rice/Chawal','Spring Onion/Hara Pyaaz','Garam Masala','Coconut Milk/Nariyal Doodh','Bread','Peanut Oil/Moong Fali Tel','Sambar Powder','Capsicum/Bell Pepper/Shimla Mirch','Mushroom','Dry Ginger Powder/Saunth','Nutmeg/Jaifal','Mango/Aam',
    'Black Peppercorns/Kali Mirch','Poppy Seeds/Khus Khus','Cucumber/Kheera/Kakdi','Mustard/Sarso','Pistachios/Pista','Lemon/Nimbu','Okra/LadyFinger/Bhindi','Ginger Garlic Paste','Sev','Spinach/Palak','Star Anise/Chakriphool',
    'Sugar/Cheeni','Tomato Puree','Banana/Kela','Oregano','Pigeon Pea Lentils/Arhar Dal/Tuvar Dal','Vegetable Stock','Green Gram/Moong Dal','Pomegranate/Anaar','Flattened Rice/Poha','Caraway Seeds/Shahi Jeera','Vanilla Extract','Baby Corn','Yeast','Corn Starch/Corn Flour',
    'Pomegranate Seeds/Anardana','Strawberry','Rose Water/Gulab Jal','Nigella Seeds/Kalonji','Vinegar/Sirka','Piece Stone Flower/Dagad Phool','Sunflower Oil','White Pepper/Safed Mirch','Basil Leaves/Tulsi',
    'Water Chestnut Flour/Paniphal Flour/Singhare Ka Atta','Green Chutney/Coriander Chutney','Buckwheat Flour/Kuttu Atta','Cheese','Dates/Khajoor','Walnut/Akhrot','Tomato Ketchup/Sauce','Bread Crumbs','Corn/Makki','Beetroot/Beets/Chukandar','Dill Leaves/Savaa Patta','Pumpkin/Kaddu','Rose Syrup','Yam/Jimikand/Suran/Garadu',
    'Sunflower Seeds/Surajmukhi Beej','Kapok Buds/Marathi Moggu','Kokum','Galangal/Kulanjan','Sweet Potatoes/Shakarkandi','Indian Gooseberry/Amla','Ash Gourd/Petha','Pav Bhaji Masala','Puffed Rice/Murmura','Red Chilli Flakes','Rose Petals/Gulab','Colocasia Leaves/Arbi Patta','Idli Rice','Cocoa Powder',
    'Semolina/Rawa/Sooji','Apple/Seb','Noodles','Fruit Salt/Eno','Lettuce','Idli Batter/Uttapam Batter','Raw Banana','Sprouted Moong Beans/Sprouts','Lemon Grass','White Chickpeas/Chole/Kabuli Chana/Safed Chana','Turmeric Leaves','Papdis',
    'Papaya/Papita','Pineapple/Ananas','Black Chickpeas/Kala Chana','Amaranth Flour/Rajgira Atta','Camphor/Kapoor','Indian Five Spice/Panch Phoron','Orange Juice/Santra Ras','Tutti Frutti','Sichuan Pepper','Coconut Chutney','Bitter Gourd/Karela',
    'Pink Lentils/Masoor Dal','Schezwan Sauce','Almond Milk','Millet Flour/Bajra Flour','Fig/Anjeer','Dry Fruits','Finger Millet Flour/Ragi Flour','Buttermilk/Chaas','Kaffir Lime','Parsley','Barnyard Millet/Sama Ke Chawal','Arrow Root Flour',
    'Brinjal/Eggplant/Baingan','Melon Seeds/Magaz','White Cowpeas/Red Cowpeas/Lobia','Lilva Beans/Hyacinth Beans/Avrekaalu','Goda Masala/Kala Masala','Colocasia Roots/Arbi','Honey/Shahad','Milk Powder','Seeraga Samba Rice','Coffee','Orange/Santra',
    'Bottle Gourd/Opo Squash/Lauki/Dudhi','Sodium Benzoate','Radish/Mooli','Chenopodium/Bathua Leaves','Saag','Maize Flour/Makki Atta','Soy Milk','Custard Powder','Khoya/Mawa','Almond Meal/Almond Paste','Flax Seeds/San Beej','Soyabean','Burger Buns','Oats','Aam Panna',
    'Sorghum Flour/Jowar Flour','Foxnuts/Lotus Seeds/Makhana','Jalapeno','Raw Mango/Kairi/Kachcha Aam','Drumstick','Kidney Beans/Rajma','Guava/Amrood','Ivy Gourds/Tendli','Tofu','Avocado','Vermicelli','Akki Shavige','Sapota/Chickoo',
    'Sandalwood Powder','Boondi','Vangi Bath Masala Powder','Smoked Paprika','Sriracha Sauce','Broccoli','Watermelon/Tarbooz','Black Peas/Kala Vatana','Tea/Chai','Agar Agar','Bengal Quince/Stone Apple/Wood Apple/Bel Fruit','Mayonnaise','Snake Gourd/Padwal/Chichinda',
    'Blueberry','Pani Puris/Golgappa Puris','Cherry','Chia Seeds','Neem','Ridge Gourd/Turai','Idli Podi','Pav','Condensed Milk','Basil Seeds/Sabja','Jackfruit/Katahal','Pointed Gourds/Parwal','Bread Croutons','Broken Wheat/Dalia','Chocolate','Marshmallow','Biscuit','Papad','Chicken','Fish','Mutton','Crab','Egg/Anda','Chive','Chipotle','Cuddapah Almond/Chironji',
    'Lychee','Apricot','Peach','Zucchini/Courgette','Zatar','Squash','Worcestershire Sauce','Thai Curry Paste','Yellow Chilli','Wonton Wrapper','Pasta','Spaghetti','Pizza Base','White Wine','Quinoa','Grape/Grapes','Whiskey','Wasabi','Vodka','Gelatin','Turnip','Tuna','Tahini','Treacle','Tobasco Sauce','Prawn',
    'Thyme','Tequila','Chhole Masala','Meat Masala','Tarragon','Olives','Prunes','Star Fruit','Squid','Soy Bean','Soup Stick','Sour Dough Starter','Shrimp','Lamb','Sherry','Screwpine','Scallop','Sausage','Salsa','Salmon','Sake','Sage','Rum','Rosemary','Red Wine','Raspberry','Rasam Powder','Quail','Pork','Pomfret','Plum',
    'Pine Nuts/Chilgoza','Gherkin','Peri Peri Masala','Pear','Passion Fruit','Oyster Sauce','Oatmeal','Nihari Masala','Nachos','Mussels','Muskmelon','Mussallam Masala','Mulberry','Muesli','Moringa Leaves','Molasses','Gun Powder/Molgapodi','Jam','Lotus Stem','Long Pepper/Pipli','Lobseter','Leek','Green Chana',
    'Kiwi','Kale','Indian Blackberry/Jamun','HP Sauce','Hazelnut','Ham','Gum/Gond','Maple Syrup','Cranberry','Couscous','Clams','Sapota/Chikoo','Biryani Masala','Beer','Barley','Barbeque Sauce','Bacon','Asparagus','Artichoke','Aioli','Alfalfa','Bok Choy','Duck','Shallot','Tapioca Flour','Amaranth'
    
]

# %%
sorted(vocabnew)
# Out:
# ['Aam Panna',
#  'Agar Agar',
#  'Aioli',
#  'Akki Shavige',
#  'Alfalfa',
#  'All Purpose Flour/Maida',
#  'Almond Meal/Almond Paste',
#  'Almond Milk',
#  'Almond/Badam',
#  'Amaranth',
#  'Amaranth Flour/Rajgira Atta',
#  'Apple/Seb',
#  'Apricot',
#  'Arrow Root Flour',
#  'Artichoke',
#  'Asafoetida/Hing',
#  'Ash Gourd/Petha',
#  'Asparagus',
#  'Avocado',
#  'Baby Corn',
#  'Bacon',
#  'Baking Powder',
#  'Baking Soda',
#  'Banana/Kela',
#  'Barbeque Sauce',
#  'Barley',
#  'Barnyard Millet/Sama Ke Chawal',
#  'Basil Leaves/Tulsi',
#  'Basil Seeds/Sabja',
#  'Basmati Rice/Basmati Chawal',
#  'Beans/Gwar Fali',
#  'Beer',
#  'Beetroot/Beets/Chukandar',
#  'Bengal Gram/Chana Dal',
#  'Bengal Quince/Stone Apple/Wood Apple/Bel Fruit',
#  'Biryani Masala',
#  'Biscuit',
#  'Bitter Gourd/Karela',
#  'Black Cardamom/Badi Elaichi',
#  'Black Chickpeas/Kala Chana',
#  'Black Gram/Urad Dal',
#  'Black Peas/Kala Vatana',
#  'Black Pepper Powder/Kaali Mirch Powder',
#  'Black Peppercorns/Kali Mirch',
#  'Black Salt/Kala Namak',
#  'Blueberry',
#  'Bok Choy',
#  'Boondi',
#  'Bottle Gourd/Opo Squash/Lauki/Dudhi',
#  'Bread',
#  'Bread Croutons',
#  'Bread Crumbs',
#  'Brinjal/Eggplant/Baingan',
#  'Broccoli',
#  'Broken Wheat/Dalia',
#  'Buckwheat Flour/Kuttu Atta',
#  'Burger Buns',
#  'Butter/Margarine/Makhan',
#  'Buttermilk/Chaas',
#  'Cabbage/Patta Gobi',
#  'Camphor/Kapoor',
#  'Capsicum/Bell Pepper/Shimla Mirch',
#  'Caraway Seeds/Shahi Jeera',
#  'Cardamom Powder/Elaichi Powder',
#  'Carrom Seeds/Ajwain',
#  'Carrot/Gajar',
#  'Cashew/Kaju',
#  'Cauliflower/Gobi',
#  'Celery/Ajwain Patta',
#  'Chaat Masala',
#  'Cheese',
#  'Chenopodium/Bathua Leaves',
#  'Cherry',
#  'Chhole Masala',
#  'Chia Seeds',
#  'Chicken',
#  'Chickpea Flour/Besan',
#  'Chipotle',
#  'Chive',
#  'Chocolate',
#  'Cilantro Leaves/Dhania Patta',
#  'Cinnamon/Dal Cheeni',
#  'Clams',
#  'Clarified Butter/Ghee',
#  'Clove/Laung',
#  'Cocoa Powder',
#  'Coconut Chutney',
#  'Coconut Milk/Nariyal Doodh',
#  'Coconut Oil/Nariyal Tel',
#  'Coconut/Nariyal',
#  'Coffee',
#  'Colocasia Leaves/Arbi Patta',
#  'Colocasia Roots/Arbi',
#  'Condensed Milk',
#  'Coriander Leaves/Dhania Patta',
#  'Coriander Powder/Dhania Powder',
#  'Coriander Seeds/Dhania Beej',
#  'Corn Starch/Corn Flour',
#  'Corn/Makki',
#  'Cottage Cheese/Paneer',
#  'Couscous',
#  'Crab',
#  'Cranberry',
#  'Cream/Malai',
#  'Cucumber/Kheera/Kakdi',
#  'Cuddapah Almond/Chironji',
#  'Cumin Powder/Jeera Powder',
#  'Cumin Seeds/Jeera',
#  'Curd/Yogurt/Dahi',
#  'Curry Leaves/Kadhi Patta',
#  'Custard Powder',
#  'Dates/Khajoor',
#  'Dill Leaves/Savaa Patta',
#  'Drumstick',
#  'Dry Fruits',
#  'Dry Ginger Powder/Saunth',
#  'Duck',
#  'Egg/Anda',
#  'Fennel Seeds/Saunf',
#  'Fenugreek Leaves/Kasuri Methi',
#  'Fenugreek Seeds/Methi',
#  'Fig/Anjeer',
#  'Finger Millet Flour/Ragi Flour',
#  'Fish',
#  'Flattened Rice/Poha',
#  'Flax Seeds/San Beej',
#  'Foxnuts/Lotus Seeds/Makhana',
#  'Fruit Salt/Eno',
#  'Galangal/Kulanjan',
#  'Garam Masala',
#  'Garlic/Lahsun',
#  'Gelatin',
#  'Gherkin',
#  'Ginger Garlic Paste',
#  'Ginger/Adrak',
#  'Goda Masala/Kala Masala',
#  'Grape/Grapes',
#  'Green Cardamom/Choti Elaichi',
#  'Green Chana',
#  'Green Chilli/Hari Mirch',
#  'Green Chutney/Coriander Chutney',
#  'Green Gram/Moong Dal',
#  'Guava/Amrood',
#  'Gum/Gond',
#  'Gun Powder/Molgapodi',
#  'HP Sauce',
#  'Ham',
#  'Hazelnut',
#  'Honey/Shahad',
#  'Ice/Baraf',
#  'Idli Batter/Uttapam Batter',
#  'Idli Podi',
#  'Idli Rice',
#  'Indian Bay Leaf/Tej Patta',
#  'Indian Blackberry/Jamun',
#  'Indian Five Spice/Panch Phoron',
#  'Indian Gooseberry/Amla',
#  'Ivy Gourds/Tendli',
#  'Jackfruit/Katahal',
#  'Jaggery/Gur',
#  'Jalapeno',
#  'Jam',
#  'Kaffir Lime',
#  'Kale',
#  'Kapok Buds/Marathi Moggu',
#  'Khoya/Mawa',
#  'Kidney Beans/Rajma',
#  'Kiwi',
#  'Kokum',
#  'Lamb',
#  'Leek',
#  'Lemon Grass',
#  'Lemon Juice/Lime Juice/Nimbu Ras',
#  'Lemon/Nimbu',
#  'Lettuce',
#  'Lilva Beans/Hyacinth Beans/Avrekaalu',
#  'Lobseter',
#  'Long Pepper/Pipli',
#  'Lotus Stem',
#  'Lychee',
#  'Mace/Javitri',
#  'Maize Flour/Makki Atta',
#  'Mango Powder/Amchur Powder',
#  'Mango/Aam',
#  'Maple Syrup',
#  'Marshmallow',
#  'Mayonnaise',
#  'Meat Masala',
#  'Melon Seeds/Magaz',
#  'Milk Powder',
#  'Milk/Doodh',
#  'Millet Flour/Bajra Flour',
#  'Mint Leaves/Pudina Patta',
#  'Molasses',
#  'Moringa Leaves',
#  'Muesli',
#  'Mulberry',
#  'Mushroom',
#  'Muskmelon',
#  'Mussallam Masala',
#  'Mussels',
#  'Mustard Oil/Sarso Tel',
#  'Mustard Seeds/Rai',
#  'Mustard/Sarso',
#  'Mutton',
#  'Nachos',
#  'Neem',
#  'Nigella Seeds/Kalonji',
#  'Nihari Masala',
#  'Noodles',
#  'Nutmeg/Jaifal',
#  'Oatmeal',
#  'Oats',
#  'Oil/Tel',
#  'Okra/LadyFinger/Bhindi',
#  'Olive Oil',
#  'Olives',
#  'Onion/Pyaaz',
#  'Orange Juice/Santra Ras',
#  'Orange/Santra',
#  'Oregano',
#  'Oyster Sauce',
#  'Pani Puris/Golgappa Puris',
#  'Papad',
#  'Papaya/Papita',
#  'Papdis',
#  'Parsley',
#  'Passion Fruit',
#  'Pasta',
#  'Pav',
#  'Pav Bhaji Masala',
#  'Peach',
#  'Peanut Oil/Moong Fali Tel',
#  'Peanuts/Moong Fali',
#  'Pear',
#  'Peas/Matar',
#  'Peri Peri Masala',
#  'Piece Stone Flower/Dagad Phool',
#  'Pigeon Pea Lentils/Arhar Dal/Tuvar Dal',
#  'Pine Nuts/Chilgoza',
#  'Pineapple/Ananas',
#  'Pink Lentils/Masoor Dal',
#  'Pistachios/Pista',
#  'Pizza Base',
#  'Plum',
#  'Pointed Gourds/Parwal',
#  'Pomegranate Seeds/Anardana',
#  'Pomegranate/Anaar',
#  'Pomfret',
#  'Poppy Seeds/Khus Khus',
#  'Pork',
#  'Potato/Aloo',
#  'Prawn',
#  'Prunes',
#  'Puffed Rice/Murmura',
#  'Pumpkin/Kaddu',
#  'Quail',
#  'Quinoa',
#  'Radish/Mooli',
#  'Raisins/KishMish',
#  'Rasam Powder',
#  'Raspberry',
#  'Raw Banana',
#  'Raw Mango/Kairi/Kachcha Aam',
#  'Red Chilli Flakes',
#  'Red Chilli Powder/Lal Mirch',
#  'Red Chilli/Lal Mirch',
#  'Red Wine',
#  'Rice Flour/Chawal Atta',
#  'Rice/Chawal',
#  'Ridge Gourd/Turai',
#  'Rose Petals/Gulab',
#  'Rose Syrup',
#  'Rose Water/Gulab Jal',
#  'Rosemary',
#  'Rum',
#  'Saag',
#  'Saffron/Kesar',
#  'Sage',
#  'Sake',
#  'Salmon',
#  'Salsa',
#  'Salt/Namak',
#  'Sambar Powder',
#  'Sandalwood Powder',
#  'Sapota/Chickoo',
#  'Sapota/Chikoo',
#  'Sausage',
#  'Scallop',
#  'Schezwan Sauce',
#  'Screwpine',
#  'Seeraga Samba Rice',
#  'Semolina/Rawa/Sooji',
#  'Sesame Oil/Til Tel',
#  'Sesame Seeds/Til',
#  'Sev',
#  'Shallot',
#  'Sherry',
#  'Shrimp',
#  'Sichuan Pepper',
#  'Smoked Paprika',
#  'Snake Gourd/Padwal/Chichinda',
#  'Sodium Benzoate',
#  'Sorghum Flour/Jowar Flour',
#  'Soup Stick',
#  'Sour Dough Starter',
#  'Soy Bean',
#  'Soy Milk',
#  'Soy Sauce',
#  'Soyabean',
#  'Spaghetti',
#  'Spinach/Palak',
#  'Spring Onion/Hara Pyaaz',
#  'Sprouted Moong Beans/Sprouts',
#  'Squash',
#  'Squid',
#  'Sriracha Sauce',
#  'Star Anise/Chakriphool',
#  'Star Fruit',
#  'Strawberry',
#  'Sugar/Cheeni',
#  'Sunflower Oil',
#  'Sunflower Seeds/Surajmukhi Beej',
#  'Sweet Potatoes/Shakarkandi',
#  'Tahini',
#  'Tamarind/Imli',
#  'Tapioca Flour',
#  'Tapioca Pearls/Sabudana',
#  'Tarragon',
#  'Tea/Chai',
#  'Tequila',
#  'Thai Curry Paste',
#  'Thyme',
#  'Tobasco Sauce',
#  'Tofu',
#  'Tomato Ketchup/Sauce',
#  'Tomato Puree',
#  'Tomato/Tamatar',
#  'Treacle',
#  'Tuna',
#  'Turmeric Leaves',
#  'Turmeric Powder/Haldi',
#  'Turnip',
#  'Tutti Frutti',
#  'Vangi Bath Masala Powder',
#  'Vanilla Extract',
#  'Vegetable Stock',
#  'Vermicelli',
#  'Vinegar/Sirka',
#  'Vodka',
#  'Walnut/Akhrot',
#  'Wasabi',
#  'Water Chestnut Flour/Paniphal Flour/Singhare Ka Atta',
#  'Water/Paani',
#  'Watermelon/Tarbooz',
#  'Wheat Flour/Atta',
#  'Whiskey',
#  'White Chickpeas/Chole/Kabuli Chana/Safed Chana',
#  'White Cowpeas/Red Cowpeas/Lobia',
#  'White Pepper/Safed Mirch',
#  'White Wine',
#  'Wonton Wrapper',
#  'Worcestershire Sauce',
#  'Yam/Jimikand/Suran/Garadu',
#  'Yeast',
#  'Yellow Chilli',
#  'Zatar',
#  'Zucchini/Courgette']

# %%
import pickle
db3=pickle.load(open('db3.p','rb'))

# %%
db3
# Out:
#                                                      URL  \
# 0      https://www.vegrecipesofindia.com/eggless-date...
# 1      https://www.vegrecipesofindia.com/eggless-oran...
# 2      https://www.vegrecipesofindia.com/eggless-bana...
# 3      https://www.vegrecipesofindia.com/punjabi-chol...
# 4      https://www.vegrecipesofindia.com/idli-recipe-...
# ...                                                  ...
# 13834  https://www.sanjeevkapoor.com/Recipe/Kozhi-Var...
# 13835  https://www.sanjeevkapoor.com/Recipe/Besan-ke-...
# 13836  https://www.sanjeevkapoor.com/Recipe/Besan-ki-...
# 13837  https://www.sanjeevkapoor.com/Recipe/Chocolate...
# 13838  https://www.sanjeevkapoor.com/Recipe/Corn-And-...
#
#                                                     Dish  \
# 0            Easy Date And Walnut Cake (Eggless + Vegan)
# 1             Orange Cake (Whole Wheat, Eggless & Vegan)
# 2            Whole Wheat Banana Cake (Eggless And Vegan)
# 3      Chana Masala | Punjabi Chole Masala (Stovetop ...
# 4                  Idli Recipe | How To Make Idli Batter
# ...                                                  ...
# 13834                                  Kozhi Vartha Kari
# 13835                                    Besan ke Laddoo
# 13836                                     Besan ki Burfi
# 13837                                    Chocolate Burfi
# 13838                              Corn And Cheese Balls
#
#                               Cuisine  Total Time  \
# 0                   (World, All, All)  (0, 1, 20)
# 1                   (World, All, All)  (0, 0, 55)
# 2              (World, American, All)  (0, 0, 40)
# 3                (Indian, North, All)  (0, 9, 45)
# 4                (Indian, South, All)  (0, 9, 25)
# ...                               ...         ...
# 13834         (Indian, South, Kerala)  (0, 0, 57)
# 13835   (Indian, West, Maharashtrian)  (0, 0, 42)
# 13836  (Indian, North, Uttar Pradesh)  (0, 0, 57)
# 13837              (Indian, All, All)  (0, 0, 42)
# 13838            (World, Fusion, All)  (0, 0, 27)
#
#                                              Ingredients    Style  Time  \
# 0      [baking powder, water, whole wheat flour, vani...    Vegan    80
# 1      [regular fine sugar, olive oil, orange juice, ...    Vegan    55
# 2      [baking powder, baking soda, whole wheat flour...    Vegan    40
# 3      [cumin seeds, water / the stock in which the c...    Vegan   585
# 4      [thick poha / thick poha flattened rice, oil a...    Vegan   565
# ...                                                  ...      ...   ...
# 13834  [chicken, dry red chillies, ginger, garlic, re...  Non-Veg    57
# 13835  [coarse gram flour (besan), cashew, almonds, g...      Veg    42
# 13836  [gram flour (besan), green cardamom powder, pi...      Veg    57
# 13837  [cocoa powder, khoya/mawa, sugar, liquid gluco...      Veg    42
# 13838  [sweet corn kernels, processed cheese, potatoe...      Veg    27
#
#       Cuisine1  Cuisine2       Cuisine3
# 0        World       All            All
# 1        World       All            All
# 2        World  American            All
# 3       Indian     North            All
# 4       Indian     South            All
# ...        ...       ...            ...
# 13834   Indian     South         Kerala
# 13835   Indian      West  Maharashtrian
# 13836   Indian     North  Uttar Pradesh
# 13837   Indian       All            All
# 13838    World    Fusion            All
#
# [13839 rows x 10 columns]

# %%
terms = ['Italian', 'Fusion']
test=db3[db3['Cuisine2'].str.contains('|'.join(terms))]

# %%
test.Cuisine2.unique()
# Out:
# array(['Italian', 'Fusion', 'Indo Italian', 'Korean/Fusion',
#        'Indo-Chinese/Fusion', 'Fusion/Italian', 'Fusion/French',
#        'Middle Eastern/Fusion', 'British/Fusion', 'Chinese/Fusion',
#        'America/Fusion', 'French/Fusion', 'Italian/British/Fusion',
#        'Italian/Spanish', 'Spanish/Italian'], dtype=object)

# %%
p=[]
if('All' in p):
    print('x')

# %%
import pandas as pd
df5=pd.DataFrame()

# %%
df5
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.concat([df5,db3])
# Out:
#                                                      URL  \
# 0      https://www.vegrecipesofindia.com/eggless-date...
# 1      https://www.vegrecipesofindia.com/eggless-oran...
# 2      https://www.vegrecipesofindia.com/eggless-bana...
# 3      https://www.vegrecipesofindia.com/punjabi-chol...
# 4      https://www.vegrecipesofindia.com/idli-recipe-...
# ...                                                  ...
# 13834  https://www.sanjeevkapoor.com/Recipe/Kozhi-Var...
# 13835  https://www.sanjeevkapoor.com/Recipe/Besan-ke-...
# 13836  https://www.sanjeevkapoor.com/Recipe/Besan-ki-...
# 13837  https://www.sanjeevkapoor.com/Recipe/Chocolate...
# 13838  https://www.sanjeevkapoor.com/Recipe/Corn-And-...
#
#                                                     Dish  \
# 0            Easy Date And Walnut Cake (Eggless + Vegan)
# 1             Orange Cake (Whole Wheat, Eggless & Vegan)
# 2            Whole Wheat Banana Cake (Eggless And Vegan)
# 3      Chana Masala | Punjabi Chole Masala (Stovetop ...
# 4                  Idli Recipe | How To Make Idli Batter
# ...                                                  ...
# 13834                                  Kozhi Vartha Kari
# 13835                                    Besan ke Laddoo
# 13836                                     Besan ki Burfi
# 13837                                    Chocolate Burfi
# 13838                              Corn And Cheese Balls
#
#                               Cuisine  Total Time  \
# 0                   (World, All, All)  (0, 1, 20)
# 1                   (World, All, All)  (0, 0, 55)
# 2              (World, American, All)  (0, 0, 40)
# 3                (Indian, North, All)  (0, 9, 45)
# 4                (Indian, South, All)  (0, 9, 25)
# ...                               ...         ...
# 13834         (Indian, South, Kerala)  (0, 0, 57)
# 13835   (Indian, West, Maharashtrian)  (0, 0, 42)
# 13836  (Indian, North, Uttar Pradesh)  (0, 0, 57)
# 13837              (Indian, All, All)  (0, 0, 42)
# 13838            (World, Fusion, All)  (0, 0, 27)
#
#                                              Ingredients    Style  Time  \
# 0      [baking powder, water, whole wheat flour, vani...    Vegan    80
# 1      [regular fine sugar, olive oil, orange juice, ...    Vegan    55
# 2      [baking powder, baking soda, whole wheat flour...    Vegan    40
# 3      [cumin seeds, water / the stock in which the c...    Vegan   585
# 4      [thick poha / thick poha flattened rice, oil a...    Vegan   565
# ...                                                  ...      ...   ...
# 13834  [chicken, dry red chillies, ginger, garlic, re...  Non-Veg    57
# 13835  [coarse gram flour (besan), cashew, almonds, g...      Veg    42
# 13836  [gram flour (besan), green cardamom powder, pi...      Veg    57
# 13837  [cocoa powder, khoya/mawa, sugar, liquid gluco...      Veg    42
# 13838  [sweet corn kernels, processed cheese, potatoe...      Veg    27
#
#       Cuisine1  Cuisine2       Cuisine3
# 0        World       All            All
# 1        World       All            All
# 2        World  American            All
# 3       Indian     North            All
# 4       Indian     South            All
# ...        ...       ...            ...
# 13834   Indian     South         Kerala
# 13835   Indian      West  Maharashtrian
# 13836   Indian     North  Uttar Pradesh
# 13837   Indian       All            All
# 13838    World    Fusion            All
#
# [13839 rows x 10 columns]

# %%
'|'.join(['Awadhi'])
# Out:
# 'Awadhi'

# %%
test1=db3[db3['Cuisine3'].str.contains('|'.join(['Awadhi']))]
test2=pd.DataFrame()

# %%
test3=pd.concat([test1,test2])

# %%
test3
# Out:
#                                                      URL  \
# 860    https://www.vegrecipesofindia.com/paneer-birya...
# 863    https://www.vegrecipesofindia.com/vegetarian-s...
# 892    https://www.vegrecipesofindia.com/vegetable-ta...
# 954    https://www.vegrecipesofindia.com/dhingri-dolm...
# 9163   https://www.sanjeevkapoor.com/Recipe/Miloni-Ma...
# 10320  https://www.sanjeevkapoor.com/Recipe/Dum-Panee...
# 12231  https://www.sanjeevkapoor.com/Recipe/Varqi-Par...
#
#                                                     Dish  \
# 860                                       Paneer Biryani
# 863             Veg Shammi Kabab | Black Chickpeas Kabab
# 892    Tehri Recipe | Vegetable Rice Recipe | How To ...
# 954                                        Dhingri Dolma
# 9163                               Miloni Matar Mushroom
# 10320                             Dum Paneer Mitti Handi
# 12231                                     Varqi Parathas
#
#                                      Cuisine  Total Time  \
# 860                  (Indian, North, Awadhi)   (0, 1, 5)
# 863                  (Indian, North, Awadhi)  (0, 7, 30)
# 892    (Indian, North, Uttar Pradesh/Awadhi)  (0, 0, 50)
# 954                  (Indian, North, Awadhi)  (0, 0, 45)
# 9163                 (Indian, North, Awadhi)  (0, 0, 22)
# 10320                (Indian, North, Awadhi)  (0, 0, 57)
# 12231                (Indian, North, Awadhi)  (0, 0, 52)
#
#                                              Ingredients        Style  Time  \
# 860    [paneer cottage cheese, ghee, garlic paste / g...  Gluten Free    65
# 863    [water /, red chilli powder, black chickpeas k...  Gluten Free   450
# 892    [ghee, lemon juice, onions, beans, green carda...  Gluten Free    50
# 954    [red chilli powder, caraway seeds shah jeera, ...  Gluten Free    45
# 9163   [green peas, mushroom, onion, oil, cinnamon, g...          Veg    22
# 10320  [paneer, yogurt, oil, bay leaf, green cardamom...          Veg    57
# 12231       [all purpose flour, ghee, milk, sugar, ghee]          Veg    52
#
#       Cuisine1 Cuisine2              Cuisine3
# 860     Indian    North                Awadhi
# 863     Indian    North                Awadhi
# 892     Indian    North  Uttar Pradesh/Awadhi
# 954     Indian    North                Awadhi
# 9163    Indian    North                Awadhi
# 10320   Indian    North                Awadhi
# 12231   Indian    North                Awadhi

# %%
db3.iloc[2073]
# Out:
# URL            https://www.sanjeevkapoor.com/Recipe/Butter-Sc...
# Dish                                         Butter Scotch Barfi
# Cuisine                              (Indian/World, Fusion, All)
# Total Time                                            (0, 3, 41)
# Ingredients    [butterscotch perla, maw (khoya), ghee, powder...
# Style                                                        Veg
# Time                                                         221
# Cuisine1                                            Indian/World
# Cuisine2                                                  Fusion
# Cuisine3                                                     All
# Name: 2073, dtype: object

# %%
df5=pd.DataFrame()
options4f=[1]
options4m=[]
if(len(options4f)!=0):
        df5f=db3.where(db3['Cuisine2'].str.contains('Fusion')).dropna()
        df5=pd.concat([df5,df5f])
    #Mughlai
if(len(options4m)!=0):
    df5m=db3.where(db3['Cuisine2'].str.contains('Mughlai'))
    df5=pd.concat([df5,df5m])
# df5=pd.concat([df5f,df5m])
#     st.write(df5)

# %%
df5
# Out:
#                                                      URL  \
# 1657   https://www.sanjeevkapoor.com/Recipe/Rawa-Toas...
# 1661   https://www.sanjeevkapoor.com/Recipe/Prawn-Oml...
# 1667   https://www.sanjeevkapoor.com/Recipe/Paneer-Ch...
# 1668   https://www.sanjeevkapoor.com/Recipe/Palak-Pan...
# 1669   https://www.sanjeevkapoor.com/Recipe/Seekh-Keb...
# ...                                                  ...
# 13805  https://www.sanjeevkapoor.com/Recipe/Spiced-Le...
# 13806  https://www.sanjeevkapoor.com/Recipe/Baked-Tom...
# 13827  https://www.sanjeevkapoor.com/Recipe/Sausage-S...
# 13832  https://www.sanjeevkapoor.com/Recipe/Self-Sauc...
# 13838  https://www.sanjeevkapoor.com/Recipe/Corn-And-...
#
#                                             Dish                      Cuisine  \
# 1657                                  Rawa Toast         (World, Fusion, All)
# 1661                               Prawn Omlette         (World, Fusion, All)
# 1667                       Paneer Chur Chur Roll  (Indian/World, Fusion, All)
# 1668                       Palak Paneer Sandwich         (World, Fusion, All)
# 1669                   Seekh Kebab Bread Omlette  (Indian/World, Fusion, All)
# ...                                          ...                          ...
# 13805                Spiced Lentils With Spinach         (World, Fusion, All)
# 13806             Baked Tomatoes A La Provencale         (World, Fusion, All)
# 13827                   Sausage Stuffed Chillies         (World, Fusion, All)
# 13832  Self Saucing Chocolate And Coffee Pudding         (World, Fusion, All)
# 13838                      Corn And Cheese Balls         (World, Fusion, All)
#
#        Total Time                                        Ingredients    Style  \
# 1657   (0, 0, 42)  [semolina (rawa/suji), bread, salt, yogurt, on...      Veg
# 1661   (0, 0, 47)  [prawns, eggs, salt, oil, green chillies, onio...  Non-Veg
# 1667   (0, 0, 47)  [paneer tikk ready made, whole wheat flour (at...      Veg
# 1668   (0, 0, 27)  [spinach leaves (palak), paneer (cottage chees...      Veg
# 1669   (0, 0, 37)  [seekh kebab, white bread, eggs, onion, tomato...  Non-Veg
# ...           ...                                                ...      ...
# 13805  (0, 0, 27)  [red lentils, baby spinach leaves, olive oil, ...      Veg
# 13806  (0, 0, 32)  [tomatoes, bread crumbs, sugar, garlic, parsle...      Veg
# 13827  (0, 0, 22)  [sausages, bhavnagri green chillies, oil, onio...  Non-Veg
# 13832  (0, 0, 22)  [dark chocolate, instant coffee powder, butter...      Veg
# 13838  (0, 0, 27)  [sweet corn kernels, processed cheese, potatoe...      Veg
#
#        Time      Cuisine1 Cuisine2 Cuisine3
# 1657   42.0         World   Fusion      All
# 1661   47.0         World   Fusion      All
# 1667   47.0  Indian/World   Fusion      All
# 1668   27.0         World   Fusion      All
# 1669   37.0  Indian/World   Fusion      All
# ...     ...           ...      ...      ...
# 13805  27.0         World   Fusion      All
# 13806  32.0         World   Fusion      All
# 13827  22.0         World   Fusion      All
# 13832  22.0         World   Fusion      All
# 13838  27.0         World   Fusion      All
#
# [3702 rows x 10 columns]

# %%
db3
# Out:
#                                                      URL  \
# 0      https://www.vegrecipesofindia.com/eggless-date...
# 1      https://www.vegrecipesofindia.com/eggless-oran...
# 2      https://www.vegrecipesofindia.com/eggless-bana...
# 3      https://www.vegrecipesofindia.com/punjabi-chol...
# 4      https://www.vegrecipesofindia.com/idli-recipe-...
# ...                                                  ...
# 13834  https://www.sanjeevkapoor.com/Recipe/Kozhi-Var...
# 13835  https://www.sanjeevkapoor.com/Recipe/Besan-ke-...
# 13836  https://www.sanjeevkapoor.com/Recipe/Besan-ki-...
# 13837  https://www.sanjeevkapoor.com/Recipe/Chocolate...
# 13838  https://www.sanjeevkapoor.com/Recipe/Corn-And-...
#
#                                                     Dish  \
# 0            Easy Date And Walnut Cake (Eggless + Vegan)
# 1             Orange Cake (Whole Wheat, Eggless & Vegan)
# 2            Whole Wheat Banana Cake (Eggless And Vegan)
# 3      Chana Masala | Punjabi Chole Masala (Stovetop ...
# 4                  Idli Recipe | How To Make Idli Batter
# ...                                                  ...
# 13834                                  Kozhi Vartha Kari
# 13835                                    Besan ke Laddoo
# 13836                                     Besan ki Burfi
# 13837                                    Chocolate Burfi
# 13838                              Corn And Cheese Balls
#
#                               Cuisine  Total Time  \
# 0                   (World, All, All)  (0, 1, 20)
# 1                   (World, All, All)  (0, 0, 55)
# 2              (World, American, All)  (0, 0, 40)
# 3                (Indian, North, All)  (0, 9, 45)
# 4                (Indian, South, All)  (0, 9, 25)
# ...                               ...         ...
# 13834         (Indian, South, Kerala)  (0, 0, 57)
# 13835   (Indian, West, Maharashtrian)  (0, 0, 42)
# 13836  (Indian, North, Uttar Pradesh)  (0, 0, 57)
# 13837              (Indian, All, All)  (0, 0, 42)
# 13838            (World, Fusion, All)  (0, 0, 27)
#
#                                              Ingredients    Style  Time  \
# 0      [baking powder, water, whole wheat flour, vani...    Vegan    80
# 1      [regular fine sugar, olive oil, orange juice, ...    Vegan    55
# 2      [baking powder, baking soda, whole wheat flour...    Vegan    40
# 3      [cumin seeds, water / the stock in which the c...    Vegan   585
# 4      [thick poha / thick poha flattened rice, oil a...    Vegan   565
# ...                                                  ...      ...   ...
# 13834  [chicken, dry red chillies, ginger, garlic, re...  Non-Veg    57
# 13835  [coarse gram flour (besan), cashew, almonds, g...      Veg    42
# 13836  [gram flour (besan), green cardamom powder, pi...      Veg    57
# 13837  [cocoa powder, khoya/mawa, sugar, liquid gluco...      Veg    42
# 13838  [sweet corn kernels, processed cheese, potatoe...      Veg    27
#
#       Cuisine1  Cuisine2       Cuisine3
# 0        World       All            All
# 1        World       All            All
# 2        World  American            All
# 3       Indian     North            All
# 4       Indian     South            All
# ...        ...       ...            ...
# 13834   Indian     South         Kerala
# 13835   Indian      West  Maharashtrian
# 13836   Indian     North  Uttar Pradesh
# 13837   Indian       All            All
# 13838    World    Fusion            All
#
# [13839 rows x 10 columns]

# %%
ing=['Chicken','Fish']
ing=list(map(str.lower,ing))
# db3[db3['Ingredients2'].str.contains('|'.join(ing))]

# %%
ing
# Out:
# ['chicken', 'fish']

# %%
db3['Ingredients'].str.contains('|'.join(ing)).dropna()
# Out:
# Series([], Name: Ingredients, dtype: float64)

# %%
s=['2 kilo chicken']

# %%
str(s)
# Out:
# "['2 kilo chicken']"

# %%
db3['Ingredients2']=db3['Ingredients'].apply(lambda x: str(x))

# %%
db3
# Out:
#                                                      URL  \
# 0      https://www.vegrecipesofindia.com/eggless-date...
# 1      https://www.vegrecipesofindia.com/eggless-oran...
# 2      https://www.vegrecipesofindia.com/eggless-bana...
# 3      https://www.vegrecipesofindia.com/punjabi-chol...
# 4      https://www.vegrecipesofindia.com/idli-recipe-...
# ...                                                  ...
# 13834  https://www.sanjeevkapoor.com/Recipe/Kozhi-Var...
# 13835  https://www.sanjeevkapoor.com/Recipe/Besan-ke-...
# 13836  https://www.sanjeevkapoor.com/Recipe/Besan-ki-...
# 13837  https://www.sanjeevkapoor.com/Recipe/Chocolate...
# 13838  https://www.sanjeevkapoor.com/Recipe/Corn-And-...
#
#                                                     Dish  \
# 0            Easy Date And Walnut Cake (Eggless + Vegan)
# 1             Orange Cake (Whole Wheat, Eggless & Vegan)
# 2            Whole Wheat Banana Cake (Eggless And Vegan)
# 3      Chana Masala | Punjabi Chole Masala (Stovetop ...
# 4                  Idli Recipe | How To Make Idli Batter
# ...                                                  ...
# 13834                                  Kozhi Vartha Kari
# 13835                                    Besan ke Laddoo
# 13836                                     Besan ki Burfi
# 13837                                    Chocolate Burfi
# 13838                              Corn And Cheese Balls
#
#                               Cuisine  Total Time  \
# 0                   (World, All, All)  (0, 1, 20)
# 1                   (World, All, All)  (0, 0, 55)
# 2              (World, American, All)  (0, 0, 40)
# 3                (Indian, North, All)  (0, 9, 45)
# 4                (Indian, South, All)  (0, 9, 25)
# ...                               ...         ...
# 13834         (Indian, South, Kerala)  (0, 0, 57)
# 13835   (Indian, West, Maharashtrian)  (0, 0, 42)
# 13836  (Indian, North, Uttar Pradesh)  (0, 0, 57)
# 13837              (Indian, All, All)  (0, 0, 42)
# 13838            (World, Fusion, All)  (0, 0, 27)
#
#                                              Ingredients    Style  Time  \
# 0      [baking powder, water, whole wheat flour, vani...    Vegan    80
# 1      [regular fine sugar, olive oil, orange juice, ...    Vegan    55
# 2      [baking powder, baking soda, whole wheat flour...    Vegan    40
# 3      [cumin seeds, water / the stock in which the c...    Vegan   585
# 4      [thick poha / thick poha flattened rice, oil a...    Vegan   565
# ...                                                  ...      ...   ...
# 13834  [chicken, dry red chillies, ginger, garlic, re...  Non-Veg    57
# 13835  [coarse gram flour (besan), cashew, almonds, g...      Veg    42
# 13836  [gram flour (besan), green cardamom powder, pi...      Veg    57
# 13837  [cocoa powder, khoya/mawa, sugar, liquid gluco...      Veg    42
# 13838  [sweet corn kernels, processed cheese, potatoe...      Veg    27
#
#       Cuisine1  Cuisine2       Cuisine3  \
# 0        World       All            All
# 1        World       All            All
# 2        World  American            All
# 3       Indian     North            All
# 4       Indian     South            All
# ...        ...       ...            ...
# 13834   Indian     South         Kerala
# 13835   Indian      West  Maharashtrian
# 13836   Indian     North  Uttar Pradesh
# 13837   Indian       All            All
# 13838    World    Fusion            All
#
#                                             Ingredients2
# 0      ['baking powder', 'water', 'whole wheat flour'...
# 1      ['regular fine sugar', 'olive oil', 'orange ju...
# 2      ['baking powder', 'baking soda', 'whole wheat ...
# 3      ['cumin seeds', 'water / the stock in which th...
# 4      ['thick poha / thick poha flattened rice', 'oi...
# ...                                                  ...
# 13834  ['chicken', 'dry red chillies', 'ginger', 'gar...
# 13835  ['coarse gram flour (besan)', 'cashew', 'almon...
# 13836  ['gram flour (besan)', 'green cardamom powder'...
# 13837  ['cocoa powder', 'khoya/mawa', 'sugar', 'liqui...
# 13838  ['sweet corn kernels', 'processed cheese', 'po...
#
# [13839 rows x 11 columns]

# %%
db3.iloc[0]['Ingredients2']
# Out:
# "['baking powder', 'water', 'whole wheat flour', 'vanilla bean powder / vanilla extract', 'baking soda', 'sunflower oil / good neutral tasting oil', 'almond milk / soy milk / oats milk', 'seedless dates', 'unrefined cane sugar regular sugar / demerara sugar', 'instant coffee', 'walnuts', 'cacao nibs / chocolate chips', 'salt', 'all purpose flour']"

# %%
import pickle
pickle.dump(db3,open('db3.p','wb'))

# %%
db33=pickle.load(open('db3.p','rb'))

# %%
db33
# Out:
#                                                      URL  \
# 0      https://www.vegrecipesofindia.com/eggless-date...
# 1      https://www.vegrecipesofindia.com/eggless-oran...
# 2      https://www.vegrecipesofindia.com/eggless-bana...
# 3      https://www.vegrecipesofindia.com/punjabi-chol...
# 4      https://www.vegrecipesofindia.com/idli-recipe-...
# ...                                                  ...
# 13834  https://www.sanjeevkapoor.com/Recipe/Kozhi-Var...
# 13835  https://www.sanjeevkapoor.com/Recipe/Besan-ke-...
# 13836  https://www.sanjeevkapoor.com/Recipe/Besan-ki-...
# 13837  https://www.sanjeevkapoor.com/Recipe/Chocolate...
# 13838  https://www.sanjeevkapoor.com/Recipe/Corn-And-...
#
#                                                     Dish  \
# 0            Easy Date And Walnut Cake (Eggless + Vegan)
# 1             Orange Cake (Whole Wheat, Eggless & Vegan)
# 2            Whole Wheat Banana Cake (Eggless And Vegan)
# 3      Chana Masala | Punjabi Chole Masala (Stovetop ...
# 4                  Idli Recipe | How To Make Idli Batter
# ...                                                  ...
# 13834                                  Kozhi Vartha Kari
# 13835                                    Besan ke Laddoo
# 13836                                     Besan ki Burfi
# 13837                                    Chocolate Burfi
# 13838                              Corn And Cheese Balls
#
#                               Cuisine  Total Time  \
# 0                   (World, All, All)  (0, 1, 20)
# 1                   (World, All, All)  (0, 0, 55)
# 2              (World, American, All)  (0, 0, 40)
# 3                (Indian, North, All)  (0, 9, 45)
# 4                (Indian, South, All)  (0, 9, 25)
# ...                               ...         ...
# 13834         (Indian, South, Kerala)  (0, 0, 57)
# 13835   (Indian, West, Maharashtrian)  (0, 0, 42)
# 13836  (Indian, North, Uttar Pradesh)  (0, 0, 57)
# 13837              (Indian, All, All)  (0, 0, 42)
# 13838            (World, Fusion, All)  (0, 0, 27)
#
#                                              Ingredients    Style  Time  \
# 0      [baking powder, water, whole wheat flour, vani...    Vegan    80
# 1      [regular fine sugar, olive oil, orange juice, ...    Vegan    55
# 2      [baking powder, baking soda, whole wheat flour...    Vegan    40
# 3      [cumin seeds, water / the stock in which the c...    Vegan   585
# 4      [thick poha / thick poha flattened rice, oil a...    Vegan   565
# ...                                                  ...      ...   ...
# 13834  [chicken, dry red chillies, ginger, garlic, re...  Non-Veg    57
# 13835  [coarse gram flour (besan), cashew, almonds, g...      Veg    42
# 13836  [gram flour (besan), green cardamom powder, pi...      Veg    57
# 13837  [cocoa powder, khoya/mawa, sugar, liquid gluco...      Veg    42
# 13838  [sweet corn kernels, processed cheese, potatoe...      Veg    27
#
#       Cuisine1  Cuisine2       Cuisine3  \
# 0        World       All            All
# 1        World       All            All
# 2        World  American            All
# 3       Indian     North            All
# 4       Indian     South            All
# ...        ...       ...            ...
# 13834   Indian     South         Kerala
# 13835   Indian      West  Maharashtrian
# 13836   Indian     North  Uttar Pradesh
# 13837   Indian       All            All
# 13838    World    Fusion            All
#
#                                             Ingredients2
# 0      ['baking powder', 'water', 'whole wheat flour'...
# 1      ['regular fine sugar', 'olive oil', 'orange ju...
# 2      ['baking powder', 'baking soda', 'whole wheat ...
# 3      ['cumin seeds', 'water / the stock in which th...
# 4      ['thick poha / thick poha flattened rice', 'oi...
# ...                                                  ...
# 13834  ['chicken', 'dry red chillies', 'ginger', 'gar...
# 13835  ['coarse gram flour (besan)', 'cashew', 'almon...
# 13836  ['gram flour (besan)', 'green cardamom powder'...
# 13837  ['cocoa powder', 'khoya/mawa', 'sugar', 'liqui...
# 13838  ['sweet corn kernels', 'processed cheese', 'po...
#
# [13839 rows x 11 columns]

# %%
cd
# Out:
# C:\Users\dhruu

# %%
db33.iloc[741][10]
# Out:
# "['curry leaves kadi patta', 'water', 'dry red chillies', 'fresh coconut', 'ginger', 'tamarind without seeds imli', 'mustard seeds/rai', 'cumin seeds/jeera', 'salt', 'green chilli', 'coconut oil / sesame oil / oil']"

# %%
#ingredient match
ing=['Cumin Seeds/Jeera']
ing=list(map(str.lower,ing))
for i in range(len(ing)):
    ing[i]='|'.join(ing[i].split('/'))
# ing=[' '.join(i.split('/') for i in ing)]

# %%
ing
# Out:
# ['cumin seeds|jeera']

# %%
db33[db33['Ingredients2'].str.contains('|'.join(ing))]
# Out:
#                                                      URL  \
# 3      https://www.vegrecipesofindia.com/punjabi-chol...
# 9      https://www.vegrecipesofindia.com/restaurant-s...
# 10     https://www.vegrecipesofindia.com/upma-savoury...
# 13     https://www.vegrecipesofindia.com/tomato-rasam...
# 14     https://www.vegrecipesofindia.com/vegetable-pu...
# ...                                                  ...
# 13790  https://www.sanjeevkapoor.com/Recipe/Yakhni-Pu...
# 13794  https://www.sanjeevkapoor.com/Recipe/Dhansaak-...
# 13823  https://www.sanjeevkapoor.com/Recipe/Bathue-Ki...
# 13824  https://www.sanjeevkapoor.com/Recipe/Steamed-M...
# 13831  https://www.sanjeevkapoor.com/Recipe/Palak-Pan...
#
#                                                     Dish  \
# 3      Chana Masala | Punjabi Chole Masala (Stovetop ...
# 9                   Dal Tadka (Stovetop And Instant Pot)
# 10                               Upma Recipe | Rava Upma
# 13     Tomato Rasam (2 Tasty Ways) | Easy Tomato Rasa...
# 14               Pulao Recipe | Vegetable Pulao In A Pot
# ...                                                  ...
# 13790                                       Yakhni Pulao
# 13794                                    Dhansaak Masala
# 13823                                    Bathue Ki Subzi
# 13824                               Steamed Moong Cheela
# 13831                                       Palak Paneer
#
#                              Cuisine  Total Time  \
# 3               (Indian, North, All)  (0, 9, 45)
# 9               (Indian, North, All)  (0, 0, 30)
# 10                (Indian, All, All)  (0, 0, 30)
# 13              (Indian, South, All)  (0, 0, 25)
# 14                (Indian, All, All)  (0, 0, 40)
# ...                              ...         ...
# 13790    (Indian, South, Hyderabadi)  (0, 0, 37)
# 13794            (World, Parsi, All)  (0, 0, 12)
# 13823  (Indian, West, Maharashtrian)  (0, 0, 12)
# 13824             (Indian, All, All)  (0, 0, 12)
# 13831       (Indian, North, Punjabi)  (0, 0, 17)
#
#                                              Ingredients    Style  Time  \
# 3      [cumin seeds, water / the stock in which the c...    Vegan   585
# 9      [cumin seeds, arhar dal tuvar dal / split pige...    Vegan    30
# 10     [green chilli, fine rawa sooji / cream wheat /...    Vegan    30
# 13     [garlic cloves, turmeric powder, cumin seeds, ...    Vegan    25
# 14     [vegetables, coriander leaves / mint leaves, p...    Vegan    40
# ...                                                  ...      ...   ...
# 13790  [chicken, basmati rice, oil, cloves, black car...  Non-Veg    37
# 13794  [fenugreek seeds (methi dana), coriander seeds...      Veg    12
# 13823  [bathua, cumin seeds, oil, ginger, garlic, dry...      Veg    12
# 13824  [whole green grams (sabut moong), banana leave...      Veg    12
# 13831  [spinach, paneer (cottage cheese), green chill...      Veg    17
#
#       Cuisine1 Cuisine2       Cuisine3  \
# 3       Indian    North            All
# 9       Indian    North            All
# 10      Indian      All            All
# 13      Indian    South            All
# 14      Indian      All            All
# ...        ...      ...            ...
# 13790   Indian    South     Hyderabadi
# 13794    World    Parsi            All
# 13823   Indian     West  Maharashtrian
# 13824   Indian      All            All
# 13831   Indian    North        Punjabi
#
#                                             Ingredients2
# 3      ['cumin seeds', 'water / the stock in which th...
# 9      ['cumin seeds', 'arhar dal tuvar dal / split p...
# 10     ['green chilli', 'fine rawa sooji / cream whea...
# 13     ['garlic cloves', 'turmeric powder', 'cumin se...
# 14     ['vegetables', 'coriander leaves / mint leaves...
# ...                                                  ...
# 13790  ['chicken', 'basmati rice', 'oil', 'cloves', '...
# 13794  ['fenugreek seeds (methi dana)', 'coriander se...
# 13823  ['bathua', 'cumin seeds', 'oil', 'ginger', 'ga...
# 13824  ['whole green grams (sabut moong)', 'banana le...
# 13831  ['spinach', 'paneer (cottage cheese)', 'green ...
#
# [2506 rows x 11 columns]

# %%
db33=db33.drop(['Ingredients'],axis=1)
db33.drop_duplicates(inplace=True)

# %%
len(db33.URL.unique())
# Out:
# 13395

# %%
db33.style.hide_index()['Dish']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-5336fe491cd6> in <module>
# ----> 1 db33.style.hide_index()['Dish']
#
# TypeError: 'Styler' object is not subscriptable

# %%
db33[['Dish']]
# Out:
#                                                     Dish
# 0            Easy Date And Walnut Cake (Eggless + Vegan)
# 1             Orange Cake (Whole Wheat, Eggless & Vegan)
# 2            Whole Wheat Banana Cake (Eggless And Vegan)
# 3      Chana Masala | Punjabi Chole Masala (Stovetop ...
# 4                  Idli Recipe | How To Make Idli Batter
# ...                                                  ...
# 13834                                  Kozhi Vartha Kari
# 13835                                    Besan ke Laddoo
# 13836                                     Besan ki Burfi
# 13837                                    Chocolate Burfi
# 13838                              Corn And Cheese Balls
#
# [13839 rows x 1 columns]

# %%
db33.iloc[0]['URL']
# Out:
# 'https://www.vegrecipesofindia.com/eggless-dates-walnut-coffee-cake/'

# %%
df = pd.DataFrame({'url':['http://google.com', 'http://duckduckgo.com'],'name':['A','B']})
def make_clickable(val): 
    return '<a href="{}">{}</a>'.format(val,val)
df.style.format({'url': make_clickable})
# Out:
# <style  type="text/css" >
# </style><table id="T_86363570_ea19_11ea_a486_90324b349074" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >url</th>        <th class="col_heading level0 col1" >name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86363570_ea19_11ea_a486_90324b349074level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_86363570_ea19_11ea_a486_90324b349074row0_col0" class="data row0 col0" ><a href="http://google.com">http://google.com</a></td>
#                         <td id="T_86363570_ea19_11ea_a486_90324b349074row0_col1" class="data row0 col1" >A</td>
#             </tr>
#             <tr>
#                         <th id="T_86363570_ea19_11ea_a486_90324b349074level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_86363570_ea19_11ea_a486_90324b349074row1_col0" class="data row1 col0" ><a href="http://duckduckgo.com">http://duckduckgo.com</a></td>
#                         <td id="T_86363570_ea19_11ea_a486_90324b349074row1_col1" class="data row1 col1" >B</td>
#             </tr>
#     </tbody></table>

# %%
data = [dict(name='Google', url='http://www.google.com'),
        dict(name='Stackoverflow', url='http://stackoverflow.com')]
df = pd.DataFrame(data)
# def make_clickable(url, name):
#     return '<a href="{} rel="noopener noreferrer" target="_blank">{}</a>'.format(url,name)

# df['name'] = df.apply(lambda x: make_clickable(x['url'], x['name']), axis=1)

# %%
df
# Out:
#             name                       url
# 0         Google     http://www.google.com
# 1  Stackoverflow  http://stackoverflow.com

# %%
df['nameurl'] = df['name'] + '#' + df['url']
def make_clickable_both(val): 
    name, url = val.split('#')
    return f'<a href="{url}">{name}</a>'
a=df.style.format({'nameurl': make_clickable_both})

# %%
a
# Out:
# <style  type="text/css" >
# </style><table id="T_7a150e46_ea21_11ea_ad4c_90324b349074" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >url</th>        <th class="col_heading level0 col2" >nameurl</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7a150e46_ea21_11ea_ad4c_90324b349074level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7a150e46_ea21_11ea_ad4c_90324b349074row0_col0" class="data row0 col0" >Google</td>
#                         <td id="T_7a150e46_ea21_11ea_ad4c_90324b349074row0_col1" class="data row0 col1" >http://www.google.com</td>
#                         <td id="T_7a150e46_ea21_11ea_ad4c_90324b349074row0_col2" class="data row0 col2" ><a href="http://www.google.com">Google</a></td>
#             </tr>
#             <tr>
#                         <th id="T_7a150e46_ea21_11ea_ad4c_90324b349074level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7a150e46_ea21_11ea_ad4c_90324b349074row1_col0" class="data row1 col0" >Stackoverflow</td>
#                         <td id="T_7a150e46_ea21_11ea_ad4c_90324b349074row1_col1" class="data row1 col1" >http://stackoverflow.com</td>
#                         <td id="T_7a150e46_ea21_11ea_ad4c_90324b349074row1_col2" class="data row1 col2" ><a href="http://stackoverflow.com">Stackoverflow</a></td>
#             </tr>
#     </tbody></table>

# %%
for i in range(len(df)):
    df.iloc[i][2]
